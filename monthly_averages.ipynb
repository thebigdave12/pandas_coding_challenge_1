# %% [markdown]
# # Monthly Averages Coding Challenge

# %% [markdown]
# ### Instructions:

# %% [markdown]
# Using the 'avocados.csv' file, complete the following tasks:
#
# 1. Load the csv into a DataFrame
#
#
# 2. Create a new DataFrame of the **monthly averages** of the 'AveragePrice' column. Your new DataFrame should have two columns - 'date' and 'average_price' with one price listed per month which represents an average of all entries from that month.
#
#
# 3. Plot the monthly average prices in a line plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set()

# %%
avocados_df = pd.read_csv("avocado.csv", index_col=False)

# %%
avocados_df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocados_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocados_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
avocados_df["Date"] = pd.to_datetime(avocados_df['Date'])

# %%
monthly_averages = pd.DataFrame(data=avocados_df.groupby(pd.PeriodIndex(avocados_df['Date'], freq='M'))['AveragePrice'].mean())

# %%
monthly_averages.head()
# Out:
#       Date  AveragePrice
# 0  2015-01      1.365046
# 1  2015-02      1.326944
# 2  2015-03      1.361981
# 3  2015-04      1.383449
# 4  2015-05      1.344685

# %%
monthly_averages.reset_index(inplace=True)

# %%
monthly_averages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          39 non-null     object
#  1   AveragePrice  39 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 752.0+ bytes

# %%
monthly_averages.Date = monthly_averages.Date.astype(str)

# %%
plt.figure(figsize=(10,8))

plt.xticks(rotation=80, fontsize=12)

ax = sns.lineplot(data=monthly_averages, x="Date", y="AveragePrice")

plt.ylim(0,2)
# Out:
# (0.0, 2.0)

# %%
plt.figure(figsize=(20,8))

plt.xticks(rotation=70, fontsize=14)

ax = sns.lineplot(data=avocados_df, x="Date", y="AveragePrice")

plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
month_avocados_df.head()

# %%
new_df = avocados_df[["Date", "AveragePrice"]]

# %%
new_df.head()
# Out:
#         Date  AveragePrice
# 0 2015-12-27          1.33
# 1 2015-12-20          1.35
# 2 2015-12-13          0.93
# 3 2015-12-06          1.08
# 4 2015-11-29          1.28

# %% [markdown]
# ### Example of new DataFrame:

# %% [markdown]
# ![monthly_avg_df.png](attachment:monthly_avg_df.png)

# %% [markdown]
# ### Example of line plot:

# %% [markdown]
# ![avocado_avg_price_lineplot.png](attachment:avocado_avg_price_lineplot.png)
